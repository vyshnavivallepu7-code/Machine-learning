# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshnavivallepu7-code/Machine-learning/blob/main/ipl_exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
# Load dataset
df = pd.read_csv("/content/drive/MyDrive/datasets/ipl.csv")

# %%
df.columns
# Out:
# Index(['PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
# Display dataset
print(df.head())
# Out:
#     PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  \
# 0   Abdulla, YA    2      SA  KXIP   Allrounder       0       0           0
# 1  Abdur Razzak    2     BAN   RCB       Bowler     214      18         657
# 2   Agarkar, AB    2     IND   KKR       Bowler     571      58        1269
# 3     Ashwin, R    1     IND   CSK       Bowler     284      31         241
# 4  Badrinath, S    2     IND   CSK      Batsman      63       0          79
#
#    ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0      0.00         0  ...    0.00       0     307    15   20.47   8.90
# 1     71.41       185  ...    0.00       0      29     0    0.00  14.50
# 2     80.62       288  ...  121.01       5    1059    29   36.52   8.81
# 3     84.56        51  ...   76.32       0    1125    49   22.96   6.23
# 4     45.93         0  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
# Correlation matrix
numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()

# %%
import seaborn as sns

# Correlation matrix
numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Remove missing values
df = df.dropna()

# %%
# Select numeric features
numeric_df = df.select_dtypes(include='number')

# %%
# Target column
print(df.columns)
# Out:
# Index(['PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df
# Out:
#       PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0     Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1    Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2     Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3       Ashwin, R    1     IND    CSK       Bowler     284      31
# 4    Badrinath, S    2     IND    CSK      Batsman      63       0
# ..            ...  ...     ...    ...          ...     ...     ...
# 125     Yadav, AS    2     IND     DC      Batsman       0       0
# 126   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS  \
# 0             0      0.00         0  ...    0.00       0     307    15
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Correlation matrix
numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()
